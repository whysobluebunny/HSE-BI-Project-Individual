# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv', sep = ',')
df = df.replace(',', '.', regex=True)
df = df.astype(float)
df = df.rename(index={0: 'KDM1A', 1: 'H2A', 2: 'H2B', 3: 'H3', 4: 'H4'})
df
# Out:
#             human       mouse   zebrafish  c.elegans  drosophila    ciliate  \
# KDM1A  300.000000  300.000000  300.000000  63.570248  300.000000  17.235077
# H2A     79.348722   25.787812   25.906578  21.892790   21.098542  19.568636
# H2B     44.246417   44.488117   39.638272  24.364516   17.795880  17.493495
# H3      42.823909   42.978811   43.242604  42.821023   43.489455  40.764472
# H4      41.640165   41.795880   42.345823  42.396856   41.889410  19.555955
#
#            yeast  methanocaldococcus  thermococcus    e.coli  tuberculosis
# KDM1A  10.385103            2.698970      3.103474  1.920819      4.244888
# H2A    21.756962            0.200659     -0.342423  0.356547     -0.724276
# H2B    23.790485           -0.278754     -0.204120 -0.602060      0.346787
# H3     42.709965            1.102373     -0.204120  0.823909     -0.505150
# H4     27.391474            0.207608      0.207608 -0.041393      1.494850

# %%
f, ax = plt.subplots(figsize=(20,5))
colors = ['#000000','#1c001a','#290026','#40003b','#52024b','#b700cf','#ffffff']
ax = sns.heatmap(df, cmap = colors, annot = df)
ax.set_yticklabels(df.index.values)
plt.show()
